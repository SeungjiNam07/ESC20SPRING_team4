# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("C:/Users/seung/Desktop/finalproject/ESC20SPRING_team4/modeling/test/데이터/imputed_transformed_test.csv")

# %%
from sklearn.preprocessing import StandardScaler

# %%
data.columns
# Out:
# Index(['Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr9', 'Attr10',
#        'Attr12', 'Attr13', 'Attr15', 'Attr19', 'Attr21', 'Attr23', 'Attr24',
#        'Attr27', 'Attr29', 'Attr30', 'Attr31', 'Attr33', 'Attr39', 'Attr41',
#        'Attr42', 'Attr43', 'Attr45', 'Attr46', 'Attr47', 'Attr52', 'Attr53',
#        'Attr55', 'Attr58', 'Attr59', 'Attr61', 'Attr64', 'Attr65', 'Attr66',
#        'Attr67', 'Attr68', 'Attr69', 'Attr70'],
#       dtype='object')

# %%
data.shape
# Out:
# (2937, 40)

# %%
data.head()
# Out:
#       Attr1     Attr2     Attr3     Attr4    Attr5     Attr6     Attr9  \
# 0  0.056456  0.421949  0.212180  0.634034  48.8550  0.155880  0.754195
# 1 -0.008610  0.445339  0.244350  0.615672   4.2847  0.000000  1.244155
# 2  0.092538  0.439267  0.343680  1.123305  -5.6058  0.153620  0.742556
# 3  0.065102  0.586252 -0.051197 -0.109960 -64.4640  0.065102  0.695145
# 4  0.233410  0.407729  0.445020  0.690243  39.9890 -0.010996  1.297463
#
#      Attr10    Attr12    Attr13  ...   Attr58    Attr59    Attr61    Attr64  \
# 0  0.403530  0.308557  0.151940  ...  0.88816  3.297571  2.781901  0.919286
# 1  0.438980 -0.029984  0.066923  ...  1.00340  3.284185  3.355084  1.836143
# 2  0.433420  0.719073  0.164560  ...  0.90805  3.304336  3.196426  1.273378
# 3  0.089501  0.060648  0.052877  ...  0.99606  3.392967  2.969470  1.255217
# 4  0.496600  0.666227  0.120340  ...  0.88972  3.272917  3.568518  3.249327
#
#      Attr65    Attr66    Attr67     Attr68    Attr69  Attr70
# ...

# %%
scale = data.drop(["Attr70"], axis =1)
scale = StandardScaler().fit_transform(scale)
scale =pd.DataFrame(scale)
scale.columns =data.columns[:(data.shape[1]-1)]
data = pd.DataFrame(pd.concat([scale,data[['Attr70']]], axis =1))

# %%
data.head()
# Out:
#       Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr9  \
# 0  0.037825  0.060273  0.024793  0.035796  0.010388  0.043156 -0.369302
# 1 -0.095902  0.142832  0.028682  0.017946  0.007754  0.025901  0.908534
# 2  0.111983  0.121400  0.040689  0.511446  0.007169  0.042905 -0.399657
# 3  0.055595  0.640189 -0.007044 -0.687485  0.003691  0.033107 -0.523307
# 4  0.401511  0.010085  0.052940  0.090441  0.009864  0.024684  1.047565
#
#      Attr10    Attr12    Attr13  ...    Attr58    Attr59    Attr61    Attr64  \
# 0  0.017295 -0.004252 -0.022610  ... -0.044731  0.089283 -0.834490 -0.832522
# 1  0.021575 -0.005872 -0.025504  ... -0.022427 -0.001657  0.735208 -0.064229
# 2  0.020904 -0.002288 -0.022180  ... -0.040881  0.135242  0.300712 -0.535806
# 3 -0.020622 -0.005438 -0.025983  ... -0.023848  0.737381 -0.320820 -0.551024
# 4  0.028532 -0.002540 -0.023686  ... -0.044429 -0.078210  1.319713  1.119969
#
#      Attr65    Attr66    Attr67    Attr68    Attr69  Attr70
# ...

# %%
corrMat= data.corr()
for i in range(corrMat.shape[0]):
    for j in range(corrMat.shape[1]):
        if (corrMat.iloc[i,j]>= 0.8) & (corrMat.iloc[i,j]<1):
            print(corrMat.columns[i], corrMat.columns[j], corrMat.iloc[i,j])
# Out:
# Attr3 Attr6 0.9969205734300448
# Attr3 Attr10 0.9990169107830762
# Attr6 Attr3 0.9969205734300448
# Attr6 Attr10 0.9969563197371032
# Attr10 Attr3 0.9990169107830762
# Attr10 Attr6 0.9969563197371032
# Attr13 Attr31 0.9998253048849471
# Attr19 Attr23 0.9995295659943679
# Attr19 Attr65 0.9345230039576907
# Attr23 Attr19 0.9995295659943679
# Attr23 Attr65 0.939067880190578
# Attr31 Attr13 0.9998253048849471
# Attr65 Attr19 0.9345230039576907
# Attr65 Attr23 0.939067880190578

# %%
data.to_csv("C:/Users/seung/Desktop/finalproject/ESC20SPRING_team4/modeling/test/데이터/scaled_test.csv",index = False)
